# %% [markdown]
# > ## Preprocessing Historical Rental price data

# %% [markdown]
# Before starting this section, the historical rental price excel file should be downloaded and save to ..data/landing under the name historical data.xlsx

# %% [markdown]
# Link to download: [Historical Rental Price](https://www.dffh.vic.gov.au/moving-annual-rents-suburb-march-quarter-2023-excel)

# %% [markdown]
# In this section, we will clean this excel file and convert it into a usable format. Then save the cleaned dataframes under ..data/curated/historical

# %% [markdown]
# > ### Import libraries and functions

# %%
# %run ../scripts/'historical data.py'
import pandas as pd
import os

# %% [markdown]
# > ### Read Excel file into csv

# %% [markdown]
# Because the excel file contains multiple sheets representing different types of property, we will read each sheet into individual csv files and save under ..data/landing/historical split

# %%
# Read the Excel file and get all sheet names
xls = pd.ExcelFile('../data/landing/historical data.xlsx')
sheet_names = xls.sheet_names  # Get all sheet names

# Create a new folder to store the splitted sheets
folder_path = '../data/raw/historical split'

# Loop through each sheet and save it as a separate CSV file
for sheet in sheet_names:
    df = pd.read_excel('../data/landing/historical data.xlsx', sheet_name=sheet)
    csv_file = f"{sheet}.csv"  # Name the CSV file based on the sheet name
    file_path = os.path.join(folder_path, csv_file)
    
    # Create the folder if it is not existed
    if not os.path.exists(folder_path):
        os.makedirs(folder_path)

    df.to_csv(file_path, index=False)   # save under ..data/landing/historical split
    print(f"Saved {csv_file} under {folder_path}")
# Out:
# Saved 1 bedroom flat.csv under ../data/raw/historical split
# Saved 2 bedroom flat.csv under ../data/raw/historical split
# Saved 3 bedroom flat.csv under ../data/raw/historical split
# Saved 2 bedroom house.csv under ../data/raw/historical split
# Saved 3 bedroom house.csv under ../data/raw/historical split
# Saved 4 bedroom house.csv under ../data/raw/historical split
# Saved All properties.csv under ../data/raw/historical split

# %% [markdown]
# > ### Load new csv files

# %%
one_bed_flat = pd.read_csv('../data/raw/historical split/1 bedroom flat.csv')
two_bed_flat = pd.read_csv('../data/raw/historical split/2 bedroom flat.csv')
three_bed_flat = pd.read_csv('../data/raw/historical split/3 bedroom flat.csv')
two_bed_house = pd.read_csv('../data/raw/historical split/2 bedroom house.csv')
three_bed_house = pd.read_csv('../data/raw/historical split/3 bedroom house.csv')
four_bed_house = pd.read_csv('../data/raw/historical split/4 bedroom house.csv')
all_properties = pd.read_csv('../data/raw/historical split/All properties.csv')

# %% [markdown]
# Now we will look at the csv file for the 1-bedroom flats data.

# %%
one_bed_flat
# Out:
#     Moving annual rent by suburb                             Unnamed: 1  \
# 0                 1 bedroom flat                                    NaN
# 1                            NaN                                    NaN
# 2                Inner Melbourne  Albert Park-Middle Park-West St Kilda
# 3                            NaN                               Armadale
# 4                            NaN                          Carlton North
# ..                           ...                                    ...
# 156                          NaN                            Wanagaratta
# 157                          NaN                               Warragul
# 158                          NaN                            Warrnambool
# 159                          NaN                                Wodonga
# 160                          NaN                            Group Total
#
#     Lease commenced in year ending  Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 0                          Mar 2000        NaN   Jun 2000        NaN
# 1                             Count     Median      Count     Median
# 2                               352        165        347        165
# 3                               210        150        212        150
# 4                                87        150         78        155
# ..                              ...        ...        ...        ...
# 156                              51         85         46         85
# 157                              13         80         11         75
# 158                             113         75        104         75
# 159                              77         85         72         85
# 160                            1132         80       1125         80
#
#     Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9  ... Unnamed: 178  \
# 0     Sep 2000        NaN   Dec 2000        NaN  ...     Mar 2022
# 1        Count     Median      Count     Median  ...        Count
# 2          378        170        369        175  ...          269
# 3          213        155        213        160  ...          223
# 4           74        150         65        150  ...           79
# ..         ...        ...        ...        ...  ...          ...
# 156         44         85         47         85  ...           36
# 157         12         90         10         90  ...            -
# 158        108         75        105         80  ...           57
# 159         77         85         83         85  ...           43
# 160       1148         80       1149         80  ...          769
#
#     Unnamed: 179 Unnamed: 180 Unnamed: 181 Unnamed: 182 Unnamed: 183  \
# 0            NaN     Jun 2022          NaN     Sep 2022          NaN
# 1         Median        Count       Median        Count       Median
# 2            315          262          325          277          340
# 3            310          233          320          237          340
# 4            300           68          320           72          320
# ..           ...          ...          ...          ...          ...
# 156          213           33          220           35          220
# 157            -            -            -            -            -
# 158          240           59          240           65          240
# 159          200           36          220           44          220
# 160          210          723          220          717          225
#
#     Unnamed: 184 Unnamed: 185 Unnamed: 186 Unnamed: 187
# 0       Dec 2022          NaN     Mar 2023          NaN
# 1          Count       Median        Count       Median
# 2            260          350          262          360
# 3            238          350          204          360
# 4             71          330           64          373
# ..           ...          ...          ...          ...
# 156           41          220           42          220
# 157            -            -            -            -
# 158           60          245           59          250
# 159           51          230           51          250
# 160          708          230          736          240
#
# [161 rows x 188 columns]

# %% [markdown]
# Through inspection, we can see that these csv files are messy and have some redundant rows/columns. We will proceed to remove these redundant rows/columns.

# %% [markdown]
# We aim to get a cleaned csv file that contains only the median price by time for each suburb/area.

# %%
cleaned_one_bed_flat = remove_redundant(one_bed_flat)
cleaned_two_bed_flat = remove_redundant(two_bed_flat)
cleaned_three_bed_flat = remove_redundant(three_bed_flat)
cleaned_two_bed_house = remove_redundant(two_bed_house)
cleaned_three_bed_house = remove_redundant(three_bed_house)
cleaned_four_bed_house = remove_redundant(three_bed_house)
cleaned_all_properties = remove_redundant(all_properties)
# Out:
# /home/lqp303203/GitHub/MAST30034_Python/project-2-group-real-estate-industry-project-27/scripts/historical data.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /home/lqp303203/GitHub/MAST30034_Python/project-2-group-real-estate-industry-project-27/scripts/historical data.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /home/lqp303203/GitHub/MAST30034_Python/project-2-group-real-estate-industry-project-27/scripts/historical data.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /home/lqp303203/GitHub/MAST30034_Python/project-2-group-real-estate-industry-project-27/scripts/historical data.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /home/lqp303203/GitHub/MAST30034_Python/project-2-group-real-estate-industry-project-27/scripts/historical data.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /home/lqp303203/GitHub/MAST30034_Python/project-2-group-real-estate-industry-project-27/scripts/historical data.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /home/lqp303203/GitHub/MAST30034_Python/project-2-group-real-estate-industry-project-27/scripts/historical data.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /home/lqp303203/GitHub/MAST30034_Python/project-2-group-real-estate-industry-project-27/scripts/historical data.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /home/lqp303203/GitHub/MAST30034_Python/project-2-group-real-estate-industry-project-27/scripts/historical data.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /home/lqp303203/GitHub/MAST30034_Python/project-2-group-real-estate-industry-project-27/scripts/historical data.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /home/lqp303203/GitHub/MAST30034_Python/project-2-group-real-estate-industry-project-27/scripts/historical data.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /home/lqp303203/GitHub/MAST30034_Python/project-2-group-real-estate-industry-project-27/scripts/historical data.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /home/lqp303203/GitHub/MAST30034_Python/project-2-group-real-estate-industry-project-27/scripts/historical data.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /home/lqp303203/GitHub/MAST30034_Python/project-2-group-real-estate-industry-project-27/scripts/historical data.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
# Create a list containing these dataframes to loop through
dataframe_list = [cleaned_one_bed_flat, cleaned_two_bed_flat, cleaned_three_bed_flat, cleaned_two_bed_house,
                  cleaned_three_bed_house, cleaned_four_bed_house, cleaned_all_properties]

# %% [markdown]
# Look at a dataframe after cleaning

# %%
cleaned_one_bed_flat
# Out:
#                                     suburb Mar 2000 Jun 2000 Sep 2000  \
# 0    Albert Park-Middle Park-West St Kilda      165      165      170
# 1                                 Armadale      150      150      155
# 2                            Carlton North      150      155      150
# 3                        Carlton-Parkville      165      170      175
# 4                          CBD-St Kilda Rd      250      250      250
# ..                                     ...      ...      ...      ...
# 107        Dandenong North-Endeavour Hills      103      108      108
# 108              Narre Warren-Hampton Park       96        -      128
# 109                             Noble Park      100      100      100
# 110                               Pakenham       98      105      105
# 111                             Springvale      100      100      100
#
#     Dec 2000 Mar 2001 Jun 2001 Sep 2001 Dec 2001 Mar 2002  ... Dec 2020  \
# 0        175      180      185      190      190      195  ...      350
# 1        160      160      160      165      165      165  ...      350
# 2        150      160      160      160      160      165  ...      350
# 3        180      190      190      195      185      180  ...      340
# 4        250      255      260      260      260      265  ...      360
# ..       ...      ...      ...      ...      ...      ...  ...      ...
# 107      108      105        -        -        -        -  ...      270
# 108      135      150      153      156      156      156  ...      234
# 109      100      105      105      105      105      105  ...      245
# 110      108      105      110      110      110      110  ...        -
# 111      100      100      100      105      105      105  ...      270
#
#     Mar 2021 Jun 2021 Sep 2021 Dec 2021 Mar 2022 Jun 2022 Sep 2022 Dec 2022  \
# 0        340      330      325      320      315      325      340      350
# 1        350      350      330      315      310      320      340      350
# 2        330      320      320      300      300      320      320      330
# 3        300      290      255      250      259      269      300      309
# 4        330      320      300      300      320      340      365      390
# ..       ...      ...      ...      ...      ...      ...      ...      ...
# 107      270      273      270      270      260      270      275      278
# 108      243      247      250      280      290      300      320      326
# 109      250      245      250      250      250      250      260      260
# 110        -      295      273      280      290      270      275      265
# 111      274      280      270      270      265      270      275      280
#
#     Mar 2023
# 0        360
# 1        360
# 2        373
# 3        352
# 4        430
# ..       ...
# 107      280
# 108      345
# 109      265
# 110      260
# 111      300
#
# [105 rows x 94 columns]

# %%
# Check data type
cleaned_one_bed_flat.dtypes
# Out:
# suburb      object
# Mar 2000    object
# Jun 2000    object
# Sep 2000    object
# Dec 2000    object
#              ...
# Mar 2022    object
# Jun 2022    object
# Sep 2022    object
# Dec 2022    object
# Mar 2023    object
# Length: 94, dtype: object

# %% [markdown]
# We can see that all the redundant rows/columns have been removed and we have the csv file in a nicer format.

# %% [markdown]
# However there are still some missing values denoted as '-'. We will replace these values by the previous non-missing price.

# %% [markdown]
# Also, the rental price is not in integer type so we will cast it to integer type.

# %% [markdown]
# > ### Fill in missing values

# %% [markdown]
# We will first fill in the missing values in the first column (Mar 2000). Then we will fill in any subsequent missing values by its first previous non-NaN value. This means that the missing rental price will be filled in with the previous nearest rental price found.

# %%
# Fill in missing values in the first column

for i in range(len(dataframe_list)):
    dataframe_list[i].set_index('suburb', inplace=True)
    dataframe_list[i] = dataframe_list[i][~dataframe_list[i].apply
                                          (lambda row: all(x == '-' for x in row), axis=1)]
    for j, row in dataframe_list[i].iterrows():
        # Convert row to a Series if it is not already
        row = row.copy()
        
        # If the first entry in the row is '-', replace it with the next non '-' value
        if row[0] == '-':
            next_non_dash = row[1:].replace('-', method='bfill').iloc[0]  # Find the next non '-' value
            row[0] = next_non_dash
        
        # Assign the modified row back to the DataFrame
        dataframe_list[i].loc[j] = row
# Out:
# /tmp/ipykernel_262179/2284462167.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if row[0] == '-':
# /tmp/ipykernel_262179/2284462167.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if row[0] == '-':
# /tmp/ipykernel_262179/2284462167.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if row[0] == '-':
# /tmp/ipykernel_262179/2284462167.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if row[0] == '-':
# /tmp/ipykernel_262179/2284462167.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if row[0] == '-':
# /tmp/ipykernel_262179/2284462167.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if row[0] == '-':
# /tmp/ipykernel_262179/2284462167.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if row[0] == '-':
# /tmp/ipykernel_262179/2284462167.py:13: FutureWarning: The 'method' keyword in Series.replace is deprecated and will be removed in a future version.
#   next_non_dash = row[1:].replace('-', method='bfill').iloc[0]  # Find the next non '-' value
# /tmp/ipykernel_262179/2284462167.py:14: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   row[0] = next_non_dash
# /tmp/ipykernel_262179/2284462167.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if row[0] == '-':
# /tmp/ipykernel_262179/2284462167.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if row[0] == '-':
# /tmp/ipykernel_262179/2284462167.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if row[0] == '-':
# /tmp/ipykernel_262179/2284462167.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if row[0] == '-':
# /tmp/ipykernel_262179/2284462167.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if row[0] == '-':
# /tmp/ipykernel_262179/2284462167.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if row[0] == '-':
# /tmp/ipykernel_262179/2284462167.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if row[0] == '-':
# /tmp/ipykernel_262179/2284462167.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if row[0] == '-':
# /tmp/ipykernel_262179/2284462167.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if row[0] == '-':
# /tmp/ipykernel_262179/2284462167.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if row[0] == '-':
# /tmp/ipykernel_262179/2284462167.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if row[0] == '-':
# /tmp/ipykernel_262179/2284462167.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if row[0] == '-':
# /tmp/ipykernel_262179/2284462167.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if row[0] == '-':
# /tmp/ipykernel_262179/2284462167.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if row[0] == '-':
# /tmp/ipykernel_262179/2284462167.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if row[0] == '-':
# /tmp/ipykernel_262179/2284462167.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if row[0] == '-':
# /tmp/ipykernel_262179/2284462167.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if row[0] == '-':
# /tmp/ipykernel_262179/2284462167.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if row[0] == '-':
# /tmp/ipykernel_262179/2284462167.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if row[0] == '-':
# /tmp/ipykernel_262179/2284462167.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if row[0] == '-':
# /tmp/ipykernel_262179/2284462167.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if row[0] == '-':
# /tmp/ipykernel_262179/2284462167.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if row[0] == '-':
# /tmp/ipykernel_262179/2284462167.py:13: FutureWarning: The 'method' keyword in Series.replace is deprecated and will be removed in a future version.
#   next_non_dash = row[1:].replace('-', method='bfill').iloc[0]  # Find the next non '-' value
# /tmp/ipykernel_262179/2284462167.py:14: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   row[0] = next_non_dash
# /tmp/ipykernel_262179/2284462167.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if row[0] == '-':
# /tmp/ipykernel_262179/2284462167.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if row[0] == '-':
# /tmp/ipykernel_262179/2284462167.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if row[0] == '-':
# /tmp/ipykernel_262179/2284462167.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if row[0] == '-':
# /tmp/ipykernel_262179/2284462167.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if row[0] == '-':
# /tmp/ipykernel_262179/2284462167.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if row[0] == '-':
# /tmp/ipykernel_262179/2284462167.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if row[0] == '-':
# /tmp/ipykernel_262179/2284462167.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if row[0] == '-':
# /tmp/ipykernel_262179/2284462167.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if row[0] == '-':
# /tmp/ipykernel_262179/2284462167.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if row[0] == '-':
# /tmp/ipykernel_262179/2284462167.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if row[0] == '-':
# /tmp/ipykernel_262179/2284462167.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if row[0] == '-':
# /tmp/ipykernel_262179/2284462167.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if row[0] == '-':
# /tmp/ipykernel_262179/2284462167.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if row[0] == '-':
# /tmp/ipykernel_262179/2284462167.py:13: FutureWarning: The 'method' keyword in Series.replace is deprecated and will be removed in a future version.
#   next_non_dash = row[1:].replace('-', method='bfill').iloc[0]  # Find the next non '-' value
# /tmp/ipykernel_262179/2284462167.py:14: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   row[0] = next_non_dash
# /tmp/ipykernel_262179/2284462167.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if row[0] == '-':
# /tmp/ipykernel_262179/2284462167.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if row[0] == '-':
# /tmp/ipykernel_262179/2284462167.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if row[0] == '-':
# /tmp/ipykernel_262179/2284462167.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if row[0] == '-':
# /tmp/ipykernel_262179/2284462167.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if row[0] == '-':
# /tmp/ipykernel_262179/2284462167.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if row[0] == '-':
# /tmp/ipykernel_262179/2284462167.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if row[0] == '-':
# /tmp/ipykernel_262179/2284462167.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if row[0] == '-':
# /tmp/ipykernel_262179/2284462167.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if row[0] == '-':
# /tmp/ipykernel_262179/2284462167.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if row[0] == '-':
# /tmp/ipykernel_262179/2284462167.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if row[0] == '-':
# /tmp/ipykernel_262179/2284462167.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if row[0] == '-':
# /tmp/ipykernel_262179/2284462167.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if row[0] == '-':
# /tmp/ipykernel_262179/2284462167.py:13: FutureWarning: The 'method' keyword in Series.replace is deprecated and will be removed in a future version.
#   next_non_dash = row[1:].replace('-', method='bfill').iloc[0]  # Find the next non '-' value
# /tmp/ipykernel_262179/2284462167.py:14: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   row[0] = next_non_dash
# /tmp/ipykernel_262179/2284462167.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if row[0] == '-':
# /tmp/ipykernel_262179/2284462167.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if row[0] == '-':
# /tmp/ipykernel_262179/2284462167.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if row[0] == '-':
# /tmp/ipykernel_262179/2284462167.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if row[0] == '-':
# /tmp/ipykernel_262179/2284462167.py:13: FutureWarning: The 'method' keyword in Series.replace is deprecated and will be removed in a future version.
#   next_non_dash = row[1:].replace('-', method='bfill').iloc[0]  # Find the next non '-' value
# /tmp/ipykernel_262179/2284462167.py:14: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   row[0] = next_non_dash
# /tmp/ipykernel_262179/2284462167.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if row[0] == '-':
# /tmp/ipykernel_262179/2284462167.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if row[0] == '-':
# /tmp/ipykernel_262179/2284462167.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if row[0] == '-':
# /tmp/ipykernel_262179/2284462167.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if row[0] == '-':
# /tmp/ipykernel_262179/2284462167.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if row[0] == '-':
# /tmp/ipykernel_262179/2284462167.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if row[0] == '-':
# /tmp/ipykernel_262179/2284462167.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if row[0] == '-':
# /tmp/ipykernel_262179/2284462167.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if row[0] == '-':
# /tmp/ipykernel_262179/2284462167.py:13: FutureWarning: The 'method' keyword in Series.replace is deprecated and will be removed in a future version.
#   next_non_dash = row[1:].replace('-', method='bfill').iloc[0]  # Find the next non '-' value
# /tmp/ipykernel_262179/2284462167.py:14: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   row[0] = next_non_dash
# /tmp/ipykernel_262179/2284462167.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if row[0] == '-':
# /tmp/ipykernel_262179/2284462167.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if row[0] == '-':
# /tmp/ipykernel_262179/2284462167.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if row[0] == '-':
# /tmp/ipykernel_262179/2284462167.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if row[0] == '-':
# /tmp/ipykernel_262179/2284462167.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if row[0] == '-':
# /tmp/ipykernel_262179/2284462167.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if row[0] == '-':
# /tmp/ipykernel_262179/2284462167.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if row[0] == '-':
# /tmp/ipykernel_262179/2284462167.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if row[0] == '-':
# /tmp/ipykernel_262179/2284462167.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if row[0] == '-':
# /tmp/ipykernel_262179/2284462167.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if row[0] == '-':
# /tmp/ipykernel_262179/2284462167.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if row[0] == '-':
# /tmp/ipykernel_262179/2284462167.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if row[0] == '-':
# /tmp/ipykernel_262179/2284462167.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if row[0] == '-':
# /tmp/ipykernel_262179/2284462167.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if row[0] == '-':
# /tmp/ipykernel_262179/2284462167.py:13: FutureWarning: The 'method' keyword in Series.replace is deprecated and will be removed in a future version.
#   next_non_dash = row[1:].replace('-', method='bfill').iloc[0]  # Find the next non '-' value
# /tmp/ipykernel_262179/2284462167.py:14: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   row[0] = next_non_dash
# /tmp/ipykernel_262179/2284462167.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if row[0] == '-':
# /tmp/ipykernel_262179/2284462167.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if row[0] == '-':
# /tmp/ipykernel_262179/2284462167.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if row[0] == '-':
# /tmp/ipykernel_262179/2284462167.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if row[0] == '-':
# /tmp/ipykernel_262179/2284462167.py:13: FutureWarning: The 'method' keyword in Series.replace is deprecated and will be removed in a future version.
#   next_non_dash = row[1:].replace('-', method='bfill').iloc[0]  # Find the next non '-' value
# /tmp/ipykernel_262179/2284462167.py:14: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   row[0] = next_non_dash
# /tmp/ipykernel_262179/2284462167.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if row[0] == '-':
# /tmp/ipykernel_262179/2284462167.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if row[0] == '-':
# /tmp/ipykernel_262179/2284462167.py:13: FutureWarning: The 'method' keyword in Series.replace is deprecated and will be removed in a future version.
#   next_non_dash = row[1:].replace('-', method='bfill').iloc[0]  # Find the next non '-' value
# /tmp/ipykernel_262179/2284462167.py:14: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   row[0] = next_non_dash
# /tmp/ipykernel_262179/2284462167.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if row[0] == '-':
# /tmp/ipykernel_262179/2284462167.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if row[0] == '-':
# /tmp/ipykernel_262179/2284462167.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if row[0] == '-':
# /tmp/ipykernel_262179/2284462167.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if row[0] == '-':
# /tmp/ipykernel_262179/2284462167.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if row[0] == '-':
# /tmp/ipykernel_262179/2284462167.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if row[0] == '-':
# /tmp/ipykernel_262179/2284462167.py:13: FutureWarning: The 'method' keyword in Series.replace is deprecated and will be removed in a future version.
#   next_non_dash = row[1:].replace('-', method='bfill').iloc[0]  # Find the next non '-' value
# /tmp/ipykernel_262179/2284462167.py:14: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   row[0] = next_non_dash
# /tmp/ipykernel_262179/2284462167.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if row[0] == '-':
# /tmp/ipykernel_262179/2284462167.py:13: FutureWarning: The 'method' keyword in Series.replace is deprecated and will be removed in a future version.
#   next_non_dash = row[1:].replace('-', method='bfill').iloc[0]  # Find the next non '-' value
# /tmp/ipykernel_262179/2284462167.py:14: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   row[0] = next_non_dash
# /tmp/ipykernel_262179/2284462167.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if row[0] == '-':
# /tmp/ipykernel_262179/2284462167.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if row[0] == '-':
# /tmp/ipykernel_262179/2284462167.py:13: FutureWarning: The 'method' keyword in Series.replace is deprecated and will be removed in a future version.
#   next_non_dash = row[1:].replace('-', method='bfill').iloc[0]  # Find the next non '-' value
# /tmp/ipykernel_262179/2284462167.py:14: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   row[0] = next_non_dash
# /tmp/ipykernel_262179/2284462167.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if row[0] == '-':
# /tmp/ipykernel_262179/2284462167.py:13: FutureWarning: The 'method' keyword in Series.replace is deprecated and will be removed in a future version.
#   next_non_dash = row[1:].replace('-', method='bfill').iloc[0]  # Find the next non '-' value
# /tmp/ipykernel_262179/2284462167.py:14: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   row[0] = next_non_dash
# /tmp/ipykernel_262179/2284462167.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if row[0] == '-':
# /tmp/ipykernel_262179/2284462167.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if row[0] == '-':
# /tmp/ipykernel_262179/2284462167.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if row[0] == '-':
# /tmp/ipykernel_262179/2284462167.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if row[0] == '-':
# /tmp/ipykernel_262179/2284462167.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if row[0] == '-':
# /tmp/ipykernel_262179/2284462167.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if row[0] == '-':
# /tmp/ipykernel_262179/2284462167.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if row[0] == '-':
# /tmp/ipykernel_262179/2284462167.py:13: FutureWarning: The 'method' keyword in Series.replace is deprecated and will be removed in a future version.
#   next_non_dash = row[1:].replace('-', method='bfill').iloc[0]  # Find the next non '-' value
# /tmp/ipykernel_262179/2284462167.py:14: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   row[0] = next_non_dash
# /tmp/ipykernel_262179/2284462167.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if row[0] == '-':
# /tmp/ipykernel_262179/2284462167.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if row[0] == '-':
# /tmp/ipykernel_262179/2284462167.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if row[0] == '-':
# /tmp/ipykernel_262179/2284462167.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if row[0] == '-':
# /tmp/ipykernel_262179/2284462167.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if row[0] == '-':
# /tmp/ipykernel_262179/2284462167.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if row[0] == '-':
# /tmp/ipykernel_262179/2284462167.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if row[0] == '-':
# /tmp/ipykernel_262179/2284462167.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if row[0] == '-':
# /tmp/ipykernel_262179/2284462167.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if row[0] == '-':
# /tmp/ipykernel_262179/2284462167.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if row[0] == '-':
# /tmp/ipykernel_262179/2284462167.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if row[0] == '-':
# /tmp/ipykernel_262179/2284462167.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if row[0] == '-':
# /tmp/ipykernel_262179/2284462167.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if row[0] == '-':
# /tmp/ipykernel_262179/2284462167.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if row[0] == '-':
# /tmp/ipykernel_262179/2284462167.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if row[0] == '-':
# /tmp/ipykernel_262179/2284462167.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if row[0] == '-':
# /tmp/ipykernel_262179/2284462167.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if row[0] == '-':
# /tmp/ipykernel_262179/2284462167.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if row[0] == '-':
# /tmp/ipykernel_262179/2284462167.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if row[0] == '-':
# /tmp/ipykernel_262179/2284462167.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if row[0] == '-':
# /tmp/ipykernel_262179/2284462167.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if row[0] == '-':
# /tmp/ipykernel_262179/2284462167.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if row[0] == '-':
# /tmp/ipykernel_262179/2284462167.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if row[0] == '-':
# /tmp/ipykernel_262179/2284462167.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if row[0] == '-':
# /tmp/ipykernel_262179/2284462167.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if row[0] == '-':
# /tmp/ipykernel_262179/2284462167.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if row[0] == '-':
# /tmp/ipykernel_262179/2284462167.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if row[0] == '-':
# /tmp/ipykernel_262179/2284462167.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if row[0] == '-':
# /tmp/ipykernel_262179/2284462167.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if row[0] == '-':
# /tmp/ipykernel_262179/2284462167.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if row[0] == '-':
# /tmp/ipykernel_262179/2284462167.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if row[0] == '-':
# /tmp/ipykernel_262179/2284462167.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if row[0] == '-':
# /tmp/ipykernel_262179/2284462167.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if row[0] == '-':
# ...
#   if row[0] == '-':
# /tmp/ipykernel_262179/2284462167.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if row[0] == '-':
# /tmp/ipykernel_262179/2284462167.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if row[0] == '-':
# /tmp/ipykernel_262179/2284462167.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if row[0] == '-':
# /tmp/ipykernel_262179/2284462167.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if row[0] == '-':
# /tmp/ipykernel_262179/2284462167.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if row[0] == '-':
# /tmp/ipykernel_262179/2284462167.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if row[0] == '-':
# /tmp/ipykernel_262179/2284462167.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if row[0] == '-':
# /tmp/ipykernel_262179/2284462167.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if row[0] == '-':
# /tmp/ipykernel_262179/2284462167.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if row[0] == '-':
# /tmp/ipykernel_262179/2284462167.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if row[0] == '-':
# /tmp/ipykernel_262179/2284462167.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if row[0] == '-':
# /tmp/ipykernel_262179/2284462167.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if row[0] == '-':
# /tmp/ipykernel_262179/2284462167.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if row[0] == '-':
# /tmp/ipykernel_262179/2284462167.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if row[0] == '-':
# /tmp/ipykernel_262179/2284462167.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if row[0] == '-':
# /tmp/ipykernel_262179/2284462167.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if row[0] == '-':
# /tmp/ipykernel_262179/2284462167.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if row[0] == '-':
# /tmp/ipykernel_262179/2284462167.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if row[0] == '-':
# /tmp/ipykernel_262179/2284462167.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if row[0] == '-':
# /tmp/ipykernel_262179/2284462167.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if row[0] == '-':
# /tmp/ipykernel_262179/2284462167.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if row[0] == '-':
# /tmp/ipykernel_262179/2284462167.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if row[0] == '-':
# /tmp/ipykernel_262179/2284462167.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if row[0] == '-':
# /tmp/ipykernel_262179/2284462167.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if row[0] == '-':
# /tmp/ipykernel_262179/2284462167.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if row[0] == '-':
# /tmp/ipykernel_262179/2284462167.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if row[0] == '-':
# /tmp/ipykernel_262179/2284462167.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if row[0] == '-':
# /tmp/ipykernel_262179/2284462167.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if row[0] == '-':
# /tmp/ipykernel_262179/2284462167.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if row[0] == '-':
# /tmp/ipykernel_262179/2284462167.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if row[0] == '-':
# /tmp/ipykernel_262179/2284462167.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if row[0] == '-':
# /tmp/ipykernel_262179/2284462167.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if row[0] == '-':
# /tmp/ipykernel_262179/2284462167.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if row[0] == '-':
# /tmp/ipykernel_262179/2284462167.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if row[0] == '-':
# /tmp/ipykernel_262179/2284462167.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if row[0] == '-':
# /tmp/ipykernel_262179/2284462167.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if row[0] == '-':
# /tmp/ipykernel_262179/2284462167.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if row[0] == '-':
# /tmp/ipykernel_262179/2284462167.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if row[0] == '-':
# /tmp/ipykernel_262179/2284462167.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if row[0] == '-':
# /tmp/ipykernel_262179/2284462167.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if row[0] == '-':
# /tmp/ipykernel_262179/2284462167.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if row[0] == '-':
# /tmp/ipykernel_262179/2284462167.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if row[0] == '-':
# /tmp/ipykernel_262179/2284462167.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if row[0] == '-':
# /tmp/ipykernel_262179/2284462167.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if row[0] == '-':
# /tmp/ipykernel_262179/2284462167.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if row[0] == '-':
# /tmp/ipykernel_262179/2284462167.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if row[0] == '-':
# /tmp/ipykernel_262179/2284462167.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if row[0] == '-':
# /tmp/ipykernel_262179/2284462167.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if row[0] == '-':
# /tmp/ipykernel_262179/2284462167.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if row[0] == '-':
# /tmp/ipykernel_262179/2284462167.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if row[0] == '-':
# /tmp/ipykernel_262179/2284462167.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if row[0] == '-':
# /tmp/ipykernel_262179/2284462167.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if row[0] == '-':
# /tmp/ipykernel_262179/2284462167.py:13: FutureWarning: The 'method' keyword in Series.replace is deprecated and will be removed in a future version.
#   next_non_dash = row[1:].replace('-', method='bfill').iloc[0]  # Find the next non '-' value
# /tmp/ipykernel_262179/2284462167.py:14: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   row[0] = next_non_dash

# %%
# Fill in missing values in subsequent columns
for i in range(len(dataframe_list)):
    dataframe_list[i] = dataframe_list[i].apply(lambda row: row.replace('-', method='ffill'), axis=1)
# Out:
# /tmp/ipykernel_262179/2910000577.py:3: FutureWarning: The 'method' keyword in Series.replace is deprecated and will be removed in a future version.
#   dataframe_list[i] = dataframe_list[i].apply(lambda row: row.replace('-', method='ffill'), axis=1)
# /tmp/ipykernel_262179/2910000577.py:3: FutureWarning: The 'method' keyword in Series.replace is deprecated and will be removed in a future version.
#   dataframe_list[i] = dataframe_list[i].apply(lambda row: row.replace('-', method='ffill'), axis=1)
# /tmp/ipykernel_262179/2910000577.py:3: FutureWarning: The 'method' keyword in Series.replace is deprecated and will be removed in a future version.
#   dataframe_list[i] = dataframe_list[i].apply(lambda row: row.replace('-', method='ffill'), axis=1)
# /tmp/ipykernel_262179/2910000577.py:3: FutureWarning: The 'method' keyword in Series.replace is deprecated and will be removed in a future version.
#   dataframe_list[i] = dataframe_list[i].apply(lambda row: row.replace('-', method='ffill'), axis=1)
# /tmp/ipykernel_262179/2910000577.py:3: FutureWarning: The 'method' keyword in Series.replace is deprecated and will be removed in a future version.
#   dataframe_list[i] = dataframe_list[i].apply(lambda row: row.replace('-', method='ffill'), axis=1)
# /tmp/ipykernel_262179/2910000577.py:3: FutureWarning: The 'method' keyword in Series.replace is deprecated and will be removed in a future version.
#   dataframe_list[i] = dataframe_list[i].apply(lambda row: row.replace('-', method='ffill'), axis=1)
# /tmp/ipykernel_262179/2910000577.py:3: FutureWarning: The 'method' keyword in Series.replace is deprecated and will be removed in a future version.
#   dataframe_list[i] = dataframe_list[i].apply(lambda row: row.replace('-', method='ffill'), axis=1)

# %%
# Check a dataframe after filling in the missing values
dataframe_list[0]
# Out:
#                                       Mar 2000 Jun 2000 Sep 2000 Dec 2000  \
# suburb
# Albert Park-Middle Park-West St Kilda      165      165      170      175
# Armadale                                   150      150      155      160
# Carlton North                              150      155      150      150
# Carlton-Parkville                          165      170      175      180
# CBD-St Kilda Rd                            250      250      250      250
# ...                                        ...      ...      ...      ...
# Dandenong North-Endeavour Hills            103      108      108      108
# Narre Warren-Hampton Park                   96       96      128      135
# Noble Park                                 100      100      100      100
# Pakenham                                    98      105      105      108
# Springvale                                 100      100      100      100
#
#                                       Mar 2001 Jun 2001 Sep 2001 Dec 2001  \
# suburb
# Albert Park-Middle Park-West St Kilda      180      185      190      190
# Armadale                                   160      160      165      165
# Carlton North                              160      160      160      160
# Carlton-Parkville                          190      190      195      185
# CBD-St Kilda Rd                            255      260      260      260
# ...                                        ...      ...      ...      ...
# Dandenong North-Endeavour Hills            105      105      105      105
# Narre Warren-Hampton Park                  150      153      156      156
# Noble Park                                 105      105      105      105
# Pakenham                                   105      110      110      110
# Springvale                                 100      100      105      105
#
#                                       Mar 2002 Jun 2002  ... Dec 2020  \
# suburb                                                   ...
# Albert Park-Middle Park-West St Kilda      195      200  ...      350
# Armadale                                   165      170  ...      350
# Carlton North                              165      163  ...      350
# Carlton-Parkville                          180      180  ...      340
# CBD-St Kilda Rd                            265      260  ...      360
# ...                                        ...      ...  ...      ...
# Dandenong North-Endeavour Hills            105      105  ...      270
# Narre Warren-Hampton Park                  156      156  ...      234
# Noble Park                                 105      105  ...      245
# Pakenham                                   110      110  ...      235
# Springvale                                 105      107  ...      270
#
#                                       Mar 2021 Jun 2021 Sep 2021 Dec 2021  \
# suburb
# Albert Park-Middle Park-West St Kilda      340      330      325      320
# Armadale                                   350      350      330      315
# Carlton North                              330      320      320      300
# Carlton-Parkville                          300      290      255      250
# CBD-St Kilda Rd                            330      320      300      300
# ...                                        ...      ...      ...      ...
# Dandenong North-Endeavour Hills            270      273      270      270
# Narre Warren-Hampton Park                  243      247      250      280
# Noble Park                                 250      245      250      250
# Pakenham                                   235      295      273      280
# Springvale                                 274      280      270      270
#
#                                       Mar 2022 Jun 2022 Sep 2022 Dec 2022  \
# suburb
# Albert Park-Middle Park-West St Kilda      315      325      340      350
# Armadale                                   310      320      340      350
# Carlton North                              300      320      320      330
# Carlton-Parkville                          259      269      300      309
# CBD-St Kilda Rd                            320      340      365      390
# ...                                        ...      ...      ...      ...
# Dandenong North-Endeavour Hills            260      270      275      278
# Narre Warren-Hampton Park                  290      300      320      326
# Noble Park                                 250      250      260      260
# Pakenham                                   290      270      275      265
# Springvale                                 265      270      275      280
#
#                                       Mar 2023
# suburb
# Albert Park-Middle Park-West St Kilda      360
# Armadale                                   360
# Carlton North                              373
# Carlton-Parkville                          352
# CBD-St Kilda Rd                            430
# ...                                        ...
# Dandenong North-Endeavour Hills            280
# Narre Warren-Hampton Park                  345
# Noble Park                                 265
# Pakenham                                   260
# Springvale                                 300
#
# [104 rows x 93 columns]

# %% [markdown]
# > ### Converting into interger type

# %%
for i in range(len(dataframe_list)):
    dataframe_list[i] = dataframe_list[i].astype(int)

# %%
# Check the data type after converting
dataframe_list[0].dtypes
# Out:
# Mar 2000    int64
# Jun 2000    int64
# Sep 2000    int64
# Dec 2000    int64
# Mar 2001    int64
#             ...
# Mar 2022    int64
# Jun 2022    int64
# Sep 2022    int64
# Dec 2022    int64
# Mar 2023    int64
# Length: 93, dtype: object

# %% [markdown]
# > ### Save dataframes

# %%
# Create a new folder to store the cleaned dataframes
folder_path = '../data/curated/historical without postcode'

# Save the df from dataframe list
save_dataframes(dataframe_list, folder_path, sheet_names)
# Out:
# Saved cleaned 1 bedroom flat.csv under ../data/curated/historical without postcode
# Saved cleaned 2 bedroom flat.csv under ../data/curated/historical without postcode
# Saved cleaned 3 bedroom flat.csv under ../data/curated/historical without postcode
# Saved cleaned 2 bedroom house.csv under ../data/curated/historical without postcode
# Saved cleaned 3 bedroom house.csv under ../data/curated/historical without postcode
# Saved cleaned 4 bedroom house.csv under ../data/curated/historical without postcode
# Saved cleaned All properties.csv under ../data/curated/historical without postcode

# %% [markdown]
# > ### Splitting suburbs

# %% [markdown]
# For visualisation purpose, we will add postcode to the data. This requires splitting data into suburbs.

# %% [markdown]
# We can see that some of the suburbs in these dataframes are actually a combination of 2 to 3 suburbs. Such as Albert Park-Middle Park-West St Kilda. Therefore we will split these suburbs and copy the entries to all individual split suburbs so that the dataframe can be aggregate with other data on suburb.

# %%
# Start splitting
for i in range(len(dataframe_list)):
    dataframe_list[i] = split_suburbs(dataframe_list[i])

# %%
# Check a dataframe after splitting
dataframe_list[0]
# Out:
#             suburb  Mar 2000  Jun 2000  Sep 2000  Dec 2000  Mar 2001  \
# 0      Albert Park       165       165       170       175       180
# 1      Middle Park       165       165       170       175       180
# 2    West St Kilda       165       165       170       175       180
# 3         Armadale       150       150       155       160       160
# 4    Carlton North       150       155       150       150       160
# ..             ...       ...       ...       ...       ...       ...
# 152   Narre Warren        96        96       128       135       150
# 153   Hampton Park        96        96       128       135       150
# 154     Noble Park       100       100       100       100       105
# 155       Pakenham        98       105       105       108       105
# 156     Springvale       100       100       100       100       100
#
#      Jun 2001  Sep 2001  Dec 2001  Mar 2002  ...  Dec 2020  Mar 2021  \
# 0         185       190       190       195  ...       350       340
# 1         185       190       190       195  ...       350       340
# 2         185       190       190       195  ...       350       340
# 3         160       165       165       165  ...       350       350
# 4         160       160       160       165  ...       350       330
# ..        ...       ...       ...       ...  ...       ...       ...
# 152       153       156       156       156  ...       234       243
# 153       153       156       156       156  ...       234       243
# 154       105       105       105       105  ...       245       250
# 155       110       110       110       110  ...       235       235
# 156       100       105       105       105  ...       270       274
#
#      Jun 2021  Sep 2021  Dec 2021  Mar 2022  Jun 2022  Sep 2022  Dec 2022  \
# 0         330       325       320       315       325       340       350
# 1         330       325       320       315       325       340       350
# 2         330       325       320       315       325       340       350
# 3         350       330       315       310       320       340       350
# 4         320       320       300       300       320       320       330
# ..        ...       ...       ...       ...       ...       ...       ...
# 152       247       250       280       290       300       320       326
# 153       247       250       280       290       300       320       326
# 154       245       250       250       250       250       260       260
# 155       295       273       280       290       270       275       265
# 156       280       270       270       265       270       275       280
#
#      Mar 2023
# 0         360
# 1         360
# 2         360
# 3         360
# 4         373
# ..        ...
# 152       345
# 153       345
# 154       265
# 155       260
# 156       300
#
# [157 rows x 93 columns]

# %% [markdown]
# > ### Get postcode

# %% [markdown]
# We will use the current median rental price data scraped from domain.com.au to add the postcodes to the historical dataframes.

# %%
# Read the CSV file for 2024 median price
median_2024 = pd.read_csv('../data/raw/median price per postcode.csv')

# %%
# Make the suburbs to lowercase to merge with other historical dataframes
median_2024['suburb'] = median_2024['suburb'].str.lower()

# The 'Melbourne' suburb is 'CBD' in the historical data
# So replace 'Melbourne' by 'CBD' to merge it with historical data
median_2024['suburb'] = median_2024['suburb'].replace('melbourne', 'cbd')

# %%
# Start merging and then cleaning the merged df
merged_dataframes = []
for i in range(len(dataframe_list)):
    dataframe_list[i]['suburb'] = dataframe_list[i]['suburb'].str.lower()
    merged_df = dataframe_list[i].merge(median_2024[['postcode', 'suburb']], on='suburb', how='inner')
    cleaned_df = clean_merged_df(merged_df)
    merged_dataframes.append(cleaned_df)

# %%
# Check a dataframe after merging
merged_dataframes[0]
# Out:
#     postcode         suburb  Mar 2000  Jun 2000  Sep 2000  Dec 2000  Mar 2001  \
# 0       3206    albert park       165       165       170       175       180
# 1       3143       armadale       150       150       155       160       160
# 2       3054  carlton north       150       155       150       150       160
# 3       3053        carlton       165       170       175       180       190
# 4       3052      parkville       165       170       175       180       190
# ..       ...            ...       ...       ...       ...       ...       ...
# 64      3072        preston       100       105       107       110       110
# 65      3073      reservoir       110       110       110       115       115
# 66      3071      thornbury       105       110       110       115       115
# 67      3174     noble park       100       100       100       100       105
# 68      3171     springvale       100       100       100       100       100
#
#     Jun 2001  Sep 2001  Dec 2001  ...  Dec 2020  Mar 2021  Jun 2021  Sep 2021  \
# 0        185       190       190  ...       350       340       330       325
# 1        160       165       165  ...       350       350       350       330
# 2        160       160       160  ...       350       330       320       320
# 3        190       195       185  ...       340       300       290       255
# 4        190       195       185  ...       340       300       290       255
# ..       ...       ...       ...  ...       ...       ...       ...       ...
# 64       110       110       115  ...       340       323       320       320
# 65       115       120       120  ...       310       310       300       300
# 66       120       125       125  ...       300       300       300       295
# 67       105       105       105  ...       245       250       245       250
# 68       100       105       105  ...       270       274       280       270
#
#     Dec 2021  Mar 2022  Jun 2022  Sep 2022  Dec 2022  Mar 2023
# 0        320       315       325       340       350       360
# 1        315       310       320       340       350       360
# 2        300       300       320       320       330       373
# 3        250       259       269       300       309       352
# 4        250       259       269       300       309       352
# ..       ...       ...       ...       ...       ...       ...
# 64       300       300       310       320       320       340
# 65       300       300       300       300       310       320
# 66       290       290       290       295       300       310
# 67       250       250       250       260       260       265
# 68       270       265       270       275       280       300
#
# [69 rows x 94 columns]

# %% [markdown]
# > ### Save dataframes with postcode

# %%
# Create a new folder to store the cleaned dataframes
folder_path = '../data/curated/historical with postcode'

# Save the df from dataframe list
save_dataframes(merged_dataframes, folder_path, sheet_names)
# Out:
# Saved cleaned 1 bedroom flat.csv under ../data/curated/historical with postcode
# Saved cleaned 2 bedroom flat.csv under ../data/curated/historical with postcode
# Saved cleaned 3 bedroom flat.csv under ../data/curated/historical with postcode
# Saved cleaned 2 bedroom house.csv under ../data/curated/historical with postcode
# Saved cleaned 3 bedroom house.csv under ../data/curated/historical with postcode
# Saved cleaned 4 bedroom house.csv under ../data/curated/historical with postcode
# Saved cleaned All properties.csv under ../data/curated/historical with postcode
